# %%
#Loading Libraries
import pandas as pd
import numpy as np
import jellyfish
from collections import deque, defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Dropout, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\admin\Desktop\research\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("TensorFlow version: ", tf.__version__)
# Out:
# Num GPUs Available:  0
# Num CPUs Available:  1
# TensorFlow version:  2.15.0

# %%
#Loading Dataset
df = pd.read_csv("final.csv")
print(df.sample(n=20))
# Out:
#     Correct_Word Incorrect_Word                     Error_Type  Letter_Count  \
# 284         hymn            hym                 Silent Letters             4
# 9         school          skool  Letter-Phoneme Correspondence             6
# 390        funny           funy            Omission of Letters             5
# 201          and           andd            Addition of Letters             3
# 422      country        countyr                 Transpositions             7
# 74         night           nite  Letter-Phoneme Correspondence             5
# 305           it            itt            Addition of Letters             2
# 3           know             no                 Silent Letters             4
# 469        chair          chari                 Transpositions             5
# 485         case           caes                 Transpositions             4
# 158        judge            juj  Letter-Phoneme Correspondence             5
# 569         pool            pol            Omission of Letters             4
# 599       ghetto          getto                 Silent Letters             6
# 554        cross           cros            Omission of Letters             5
# 76        yellow        yelolow                 Transpositions             6
# 515    telephone       telefone  Letter-Phoneme Correspondence             9
# 308         love           lvoe                 Transpositions             4
# 258      ancient        anshent  Letter-Phoneme Correspondence             7
# 89          sink          sinck            Addition of Letters             4
# 240       soccer          socer            Omission of Letters             6
#
#      Difficulty_Level
# 284                 2
# 9                   3
# 390                 2
# 201                 1
# 422                 3
# 74                  2
# 305                 1
# 3                   2
# 469                 2
# 485                 1
# 158                 2
# 569                 2
# 599                 2
# 554                 2
# 76                  3
# 515                 4
# 308                 2
# 258                 3
# 89                  2
# 240                 3

# %%
# Data Preprocessing and Feature Engineering
#loading, cleaning, and processing the dataset
class DataProcessor:
    #constructor 
    def __init__(self, dataset_path):

        self.df = pd.read_csv(dataset_path)
        self.df = self.clean_dataset(self.df)

        self.correct_words = set(self.df['Correct_Word'].str.lower())
        self.incorrect_words = set(self.df['Incorrect_Word'].str.lower())

        self.all_words = pd.concat([self.df['Incorrect_Word'], self.df['Correct_Word']]).unique()
        self.unique_words = len(set(self.all_words))

        self._create_char_encoding()
        
        self.df['Error_Type'] = self.df['Error_Type'].apply(lambda x: x.split(',') if ',' in x else [x])
        self.error_types = sorted(set([et for sublist in self.df['Error_Type'] for et in sublist]))
        
        self.label_encoder = {et: i for i, et in enumerate(self.error_types)}
        self.inverse_label_encoder = {i: et for et, i in self.label_encoder.items()}

        self.max_difficulty = self.df['Difficulty_Level'].max()
        
        self.error_type_counts = {et: sum(1 for errors in self.df['Error_Type'] for e in errors if e == et)
                                 for et in self.error_types}

        print(f"Dataset rows without duplicate: {len(self.df)}")
        print(f"Error types: {self.error_types}")
        print(f"max difficulty: {self.max_difficulty}")
        print("Error type counts:")
        for et, count in self.error_type_counts.items():
            print(f"  {et}: {count}")
            
    #format that can be fed into a neural network, which can only process numerical data.
    def _create_char_encoding(self):
        chars = set(''.join(self.all_words))
        self.char_to_int = {c: i+1 for i, c in enumerate(chars)}
        self.int_to_char = {i: c for c, i in self.char_to_int.items()}
        self.max_length = int(np.percentile([len(word) for word in self.all_words], 95))

# preprocessed into a sequence of integers that represent the characters.
    def preprocess_word(self, word):
        processed = word.lower().ljust(self.max_length)[:self.max_length]
        return [self.char_to_int.get(c, 0) for c in processed]

    def decode_word(self, encoded_word):
        return ''.join([self.int_to_char.get(c, '') for c in encoded_word if c != 0])

    def phonetic_features(self, word):
        word = word.lower()
        correct_word = self.df[self.df['Incorrect_Word'] == word]['Correct_Word'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else word
        edits = jellyfish.levenshtein_distance(word, correct_word)
        transposition_flag = any(word[i:i+2] == correct_word[i+1:i-1:-1] for i in range(len(word)-1)) and len(word) == len(correct_word)
        omission_flag = len(word) < len(correct_word)
        addition_flag = len(word) > len(correct_word)
        phoneme_mismatch_flag = jellyfish.metaphone(word) != jellyfish.metaphone(correct_word) and not transposition_flag
        silent_letter_flag = edits > 0 and jellyfish.soundex(word) == jellyfish.soundex(correct_word) and not omission_flag
        return np.array([edits, transposition_flag, omission_flag, addition_flag, phoneme_mismatch_flag, silent_letter_flag], dtype=float)

    def get_difficulty(self, word):
        return self.df[self.df['Incorrect_Word'] == word]['Difficulty_Level'].iloc[0] \
            if word in self.df['Incorrect_Word'].values else 0

    def suggest_words_by_difficulty(self, difficulty, count=5):
        return self.df[self.df['Difficulty_Level'] == difficulty]['Incorrect_Word'].sample(min(count, len(self.df[self.df['Difficulty_Level'] == difficulty]))).tolist()

    def clean_dataset(self, df):
        #Marking 'Correct' for matching words:
        df.loc[df['Incorrect_Word'] == df['Correct_Word'], 'Error_Type'] = ['Correct']
        #Removing duplicate rows
        return df.drop_duplicates(subset=['Incorrect_Word', 'Correct_Word'], keep='first')

class DifficultyManager:
    def __init__(self):
        self.difficulty = 1
        self.performance = deque(maxlen=10)

    def update(self, correct):
        self.performance.append(correct)
        success_rate = np.mean(self.performance) if len(self.performance) > 0 else 0
        if success_rate > 0.7:
            self.difficulty = min(5, self.difficulty + 1)
        elif success_rate < 0.3:
            self.difficulty = max(1, self.difficulty - 1)

class GameEngine:
    def __init__(self):
        self.score = 0
        self.streak = 0
        self.level = 1

    def update(self, correct, difficulty):
        if correct:
            self.streak += 1
            self.score += (10 * difficulty) + (5 * self.streak)
            if self.score >= self.level * 100:
                self.level = min(10, self.level + 1)
        else:
            self.streak = 0
            self.score = max(0, self.score - (2 * difficulty))
            if self.score < (self.level - 1) * 100:
                self.level = max(1, self.level - 1)

# %%
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, Bidirectional, GlobalMaxPooling1D, Concatenate, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import json
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split


class SpellingTutor:
    def __init__(self, dataset_path=None, filepath=None, metadata_path=None):
        if dataset_path is None and (filepath is not None or metadata_path is not None):
            raise ValueError("You must provide either dataset_path or filepath and metadata_path.")

        self.processor = DataProcessor(dataset_path) if dataset_path else None
        self.difficulty_manager = DifficultyManager()
        self.game = GameEngine()
        self.dataset_path = dataset_path
        self.filepath = filepath
        self.metadata_path = metadata_path

        if filepath and metadata_path and dataset_path:
            self.load_model(filepath, metadata_path, dataset_path)
        elif dataset_path:
            train_df, val_df = train_test_split(self.processor.df, test_size=0.2, random_state=42)
            self.X_train_seq = np.array([self.processor.preprocess_word(w) for w in train_df['Incorrect_Word']])
            self.X_train_ph = np.array([self.processor.phonetic_features(w) for w in train_df['Incorrect_Word']])
            self.y_train_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                          for errors in train_df['Error_Type']])
            self.y_train_diff = np.array(train_df['Difficulty_Level'])
            
            self.X_val_seq = np.array([self.processor.preprocess_word(w) for w in val_df['Incorrect_Word']])
            self.X_val_ph = np.array([self.processor.phonetic_features(w) for w in val_df['Incorrect_Word']])
            self.y_val_error = np.array([[1 if et in errors else 0 for et in self.processor.error_types]
                                        for errors in val_df['Error_Type']])
            self.y_val_diff = np.array(val_df['Difficulty_Level'])
            self.val_words = val_df['Incorrect_Word'].values

            self.model = self._build_model()
            self.history = self._train_model()
            self._validate()
            self._plot_training_history()
        else:
            raise ValueError("Both dataset_path and metadata_path are not provided.")

    def _build_model(self):
        seq_inputs = Input(shape=(self.processor.max_length,))
        ph_inputs = Input(shape=(6,))
        
        # Reduce the complexity of the model: fewer LSTM units and regularization
        x = Embedding(input_dim=len(self.processor.char_to_int)+1, output_dim=128, mask_zero=True)(seq_inputs)
        x = Bidirectional(LSTM(256, return_sequences=True, dropout=0.3, kernel_regularizer=l2(0.01)))(x)
        x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, kernel_regularizer=l2(0.01)))(x)
        x = GlobalMaxPooling1D()(x)
        x = Concatenate()([x, ph_inputs])
        x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
        x = Dropout(0.4)(x)  # Increased dropout rate

        error_output = Dense(len(self.processor.error_types), activation='sigmoid', name='error_output')(x)
        diff_output = Dense(1, activation='linear', name='diff_output')(x)

        model = Model(inputs=[seq_inputs, ph_inputs], outputs=[error_output, diff_output])
        model.compile(
            loss={'error_output': 'binary_crossentropy', 'diff_output': 'mse'},
            optimizer=Adam(learning_rate=0.001),
            metrics={'error_output': 'accuracy', 'diff_output': 'mae'}
        )
        return model

    def _train_model(self):
        # Increased patience and monitoring validation loss more strictly
        history = self.model.fit(
            [self.X_train_seq, self.X_train_ph],
            {'error_output': self.y_train_error, 'diff_output': self.y_train_diff},
            epochs=100, batch_size=32,
            validation_data=([self.X_val_seq, self.X_val_ph],
                            {'error_output': self.y_val_error, 'diff_output': self.y_val_diff}),
            callbacks=[EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss'),
                       ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')],
            verbose=1
        )
        self.model.save('spelling_tutor_model.keras')

        metadata = {
            'dataset_path': self.dataset_path,
            'char_to_int': self.processor.char_to_int,
            'max_length': self.processor.max_length,
            'correct_words': list(self.processor.correct_words),
            'label_encoder': self.processor.label_encoder,
            'inverse_label_encoder': {str(k): v for k, v in self.processor.inverse_label_encoder.items()}
        }
        with open('spelling_tutor_metadata.json', 'w') as f:
            json.dump(metadata, f)
        return history

    def load_model(self, filepath, metadata_path, dataset_path):
        self.model = load_model(filepath)
        with open(metadata_path, 'r') as f:
            metadata = json.load(f)
            if 'dataset_path' in metadata and metadata['dataset_path'] != dataset_path:
                print(f"Warning: Provided dataset_path ({dataset_path}) differs from metadata ({metadata['dataset_path']})")
            self.processor.char_to_int = metadata['char_to_int']
            self.processor.max_length = metadata['max_length']
            self.processor.correct_words = set(metadata['correct_words'])
            self.processor.label_encoder = metadata['label_encoder']
            self.processor.inverse_label_encoder = {int(k): v for k, v in metadata['inverse_label_encoder'].items()}

    def _validate(self):
        error_preds, diff_preds = self.model.predict([self.X_val_seq, self.X_val_ph])
        error_acc = np.mean([np.all(pred > 0.5) == true for pred, true in zip(error_preds, self.y_val_error)])
        diff_mae = np.mean(np.abs(diff_preds.flatten() - self.y_val_diff))
        print(f"Validation Difficulty MAE: {diff_mae:.2f}")

    def _plot_training_history(self):
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(self.history.history['error_output_accuracy'], label='Training Accuracy')
        plt.plot(self.history.history['val_error_output_accuracy'], label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(self.history.history['loss'], label='Training Loss')
        plt.plot(self.history.history['val_loss'], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

    def process_word(self, word):
        correct = word.lower() in self.processor.correct_words
        seq_input = np.array([self.processor.preprocess_word(word)])
        ph_input = np.array([self.processor.phonetic_features(word)])
        error_proba, diff_pred = self.model.predict([seq_input, ph_input])

        if correct:
            error_types = ['Correct']
            confidence = 1.0
            max_confidence_type = 'Correct'
        else:
            error_types = [self.processor.inverse_label_encoder[i] for i, prob in enumerate(error_proba[0]) if prob > 0.3]
            confidences = {self.processor.inverse_label_encoder[i]: prob for i, prob in enumerate(error_proba[0]) if prob > 0.3}
            max_confidence_idx = np.argmax(error_proba[0])
            max_confidence_type = self.processor.inverse_label_encoder[max_confidence_idx]
            confidence = error_proba[0][max_confidence_idx]
            if not error_types:
                error_types = ['Unknown']
                confidences = {'Unknown': confidence}

        difficulty_pred = float(diff_pred[0][0])
        actual_difficulty = self.processor.get_difficulty(word) if not correct else 0

        self.difficulty_manager.update(correct)
        self.game.update(correct, self.difficulty_manager.difficulty)
        return {
            'word': word,
            'correct': correct,
            'error_types': error_types,
            'confidences': confidences if not correct else {'Correct': 1.0},
            'max_confidence_type': max_confidence_type,
            'confidence': confidence,
            'predicted_difficulty': round(difficulty_pred, 2),
            'actual_difficulty': actual_difficulty,
            'game_difficulty': self.difficulty_manager.difficulty,
            'score': self.game.score,
            'level': self.game.level,
            'streak': self.game.streak
        }

# %%
tutor = SpellingTutor(dataset_path="final.csv")
print("Model trained and saved!")
# Out:
# Dataset rows without duplicate: 530
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 103
#   Omission of Letters: 108
#   Silent Letters: 106
#   Transpositions: 106
# WARNING:tensorflow:From c:\Users\admin\Desktop\research\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\admin\Desktop\research\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\admin\Desktop\research\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 14/14 [==============================] - 22s 431ms/step - loss: 17.4183 - error_output_loss: 0.6871 - diff_output_loss: 3.4468 - error_output_accuracy: 0.2052 - diff_output_mae: 1.6357 - val_loss: 11.4330 - val_error_output_loss: 0.6164 - val_diff_output_loss: 0.9427 - val_error_output_accuracy: 0.2547 - val_diff_output_mae: 0.7601
# Epoch 2/100
# 14/14 [==============================] - 1s 55ms/step - loss: 9.2358 - error_output_loss: 0.6297 - diff_output_loss: 0.6039 - error_output_accuracy: 0.2406 - diff_output_mae: 0.6174 - val_loss: 6.7487 - val_error_output_loss: 0.5689 - val_diff_output_loss: 0.2131 - val_error_output_accuracy: 0.2547 - val_diff_output_mae: 0.3947
# Epoch 3/100
# 14/14 [==============================] - 1s 57ms/step - loss: 5.7975 - error_output_loss: 0.5754 - diff_output_loss: 0.4140 - error_output_accuracy: 0.2665 - diff_output_mae: 0.5173 - val_loss: 4.3093 - val_error_output_loss: 0.5326 - val_diff_output_loss: 0.2153 - val_error_output_accuracy: 0.2642 - val_diff_output_mae: 0.3898
# Epoch 4/100
# 14/14 [==============================] - 1s 55ms/step - loss: 3.7398 - error_output_loss: 0.5427 - diff_output_loss: 0.3048 - error_output_accuracy: 0.3066 - diff_output_mae: 0.4374 - val_loss: 2.8714 - val_error_output_loss: 0.5050 - val_diff_output_loss: 0.1878 - val_error_output_accuracy: 0.4906 - val_diff_output_mae: 0.3662
# Epoch 5/100
# 14/14 [==============================] - 1s 53ms/step - loss: 2.6379 - error_output_loss: 0.5191 - diff_output_loss: 0.3181 - error_output_accuracy: 0.3349 - diff_output_mae: 0.4457 - val_loss: 2.0889 - val_error_output_loss: 0.4865 - val_diff_output_loss: 0.1931 - val_error_output_accuracy: 0.5849 - val_diff_output_mae: 0.3501
# Epoch 6/100
# 14/14 [==============================] - 1s 54ms/step - loss: 1.9771 - error_output_loss: 0.4985 - diff_output_loss: 0.2825 - error_output_accuracy: 0.4033 - diff_output_mae: 0.4197 - val_loss: 1.6857 - val_error_output_loss: 0.4750 - val_diff_output_loss: 0.2297 - val_error_output_accuracy: 0.6415 - val_diff_output_mae: 0.3545
# Epoch 7/100
# 14/14 [==============================] - 1s 55ms/step - loss: 1.6181 - error_output_loss: 0.4824 - diff_output_loss: 0.2792 - error_output_accuracy: 0.4363 - diff_output_mae: 0.4089 - val_loss: 1.4130 - val_error_output_loss: 0.4684 - val_diff_output_loss: 0.2149 - val_error_output_accuracy: 0.6226 - val_diff_output_mae: 0.3491
# Epoch 8/100
# 14/14 [==============================] - 1s 58ms/step - loss: 1.3762 - error_output_loss: 0.4692 - diff_output_loss: 0.2547 - error_output_accuracy: 0.5071 - diff_output_mae: 0.3964 - val_loss: 1.2498 - val_error_output_loss: 0.4622 - val_diff_output_loss: 0.2126 - val_error_output_accuracy: 0.6132 - val_diff_output_mae: 0.3455
# Epoch 9/100
# 14/14 [==============================] - 1s 54ms/step - loss: 1.2781 - error_output_loss: 0.4650 - diff_output_loss: 0.2880 - error_output_accuracy: 0.4976 - diff_output_mae: 0.4126 - val_loss: 1.1643 - val_error_output_loss: 0.4539 - val_diff_output_loss: 0.2341 - val_error_output_accuracy: 0.5472 - val_diff_output_mae: 0.3501
# Epoch 10/100
# 14/14 [==============================] - 1s 53ms/step - loss: 1.1149 - error_output_loss: 0.4538 - diff_output_loss: 0.2217 - error_output_accuracy: 0.5307 - diff_output_mae: 0.3710 - val_loss: 1.0491 - val_error_output_loss: 0.4467 - val_diff_output_loss: 0.1999 - val_error_output_accuracy: 0.6509 - val_diff_output_mae: 0.3462
# Epoch 11/100
# 14/14 [==============================] - 1s 54ms/step - loss: 1.0749 - error_output_loss: 0.4500 - diff_output_loss: 0.2479 - error_output_accuracy: 0.5802 - diff_output_mae: 0.3871 - val_loss: 0.9916 - val_error_output_loss: 0.4379 - val_diff_output_loss: 0.2054 - val_error_output_accuracy: 0.6604 - val_diff_output_mae: 0.3688
# Epoch 12/100
# 14/14 [==============================] - 1s 55ms/step - loss: 1.0015 - error_output_loss: 0.4379 - diff_output_loss: 0.2321 - error_output_accuracy: 0.5778 - diff_output_mae: 0.3767 - val_loss: 0.9289 - val_error_output_loss: 0.4302 - val_diff_output_loss: 0.1892 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3511
# Epoch 13/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.9739 - error_output_loss: 0.4288 - diff_output_loss: 0.2501 - error_output_accuracy: 0.5967 - diff_output_mae: 0.3767 - val_loss: 0.9051 - val_error_output_loss: 0.4205 - val_diff_output_loss: 0.2087 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3750
# Epoch 14/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.9216 - error_output_loss: 0.4213 - diff_output_loss: 0.2342 - error_output_accuracy: 0.5778 - diff_output_mae: 0.3685 - val_loss: 0.8555 - val_error_output_loss: 0.4109 - val_diff_output_loss: 0.1915 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3565
# Epoch 15/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.8694 - error_output_loss: 0.4093 - diff_output_loss: 0.2147 - error_output_accuracy: 0.6085 - diff_output_mae: 0.3555 - val_loss: 0.8643 - val_error_output_loss: 0.3998 - val_diff_output_loss: 0.2334 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3942
# Epoch 16/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.8539 - error_output_loss: 0.3986 - diff_output_loss: 0.2296 - error_output_accuracy: 0.6557 - diff_output_mae: 0.3737 - val_loss: 0.8428 - val_error_output_loss: 0.3911 - val_diff_output_loss: 0.2376 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3974
# Epoch 17/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.8269 - error_output_loss: 0.3907 - diff_output_loss: 0.2263 - error_output_accuracy: 0.6297 - diff_output_mae: 0.3671 - val_loss: 0.8094 - val_error_output_loss: 0.3822 - val_diff_output_loss: 0.2270 - val_error_output_accuracy: 0.7264 - val_diff_output_mae: 0.3891
# Epoch 18/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.8235 - error_output_loss: 0.3828 - diff_output_loss: 0.2438 - error_output_accuracy: 0.6274 - diff_output_mae: 0.3708 - val_loss: 0.7824 - val_error_output_loss: 0.3759 - val_diff_output_loss: 0.2177 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3808
# Epoch 19/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.7812 - error_output_loss: 0.3706 - diff_output_loss: 0.2256 - error_output_accuracy: 0.6580 - diff_output_mae: 0.3701 - val_loss: 0.7540 - val_error_output_loss: 0.3710 - val_diff_output_loss: 0.2021 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3410
# Epoch 20/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.7840 - error_output_loss: 0.3678 - diff_output_loss: 0.2403 - error_output_accuracy: 0.6368 - diff_output_mae: 0.3787 - val_loss: 0.7727 - val_error_output_loss: 0.3672 - val_diff_output_loss: 0.2307 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3415
# Epoch 21/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.7864 - error_output_loss: 0.3639 - diff_output_loss: 0.2541 - error_output_accuracy: 0.6627 - diff_output_mae: 0.3846 - val_loss: 0.7298 - val_error_output_loss: 0.3582 - val_diff_output_loss: 0.2063 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3394
# Epoch 22/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.7861 - error_output_loss: 0.3563 - diff_output_loss: 0.2693 - error_output_accuracy: 0.6816 - diff_output_mae: 0.3996 - val_loss: 0.7392 - val_error_output_loss: 0.3490 - val_diff_output_loss: 0.2369 - val_error_output_accuracy: 0.6887 - val_diff_output_mae: 0.3994
# Epoch 23/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.7568 - error_output_loss: 0.3451 - diff_output_loss: 0.2584 - error_output_accuracy: 0.6910 - diff_output_mae: 0.4011 - val_loss: 0.7132 - val_error_output_loss: 0.3428 - val_diff_output_loss: 0.2226 - val_error_output_accuracy: 0.6604 - val_diff_output_mae: 0.3900
# Epoch 24/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.7150 - error_output_loss: 0.3427 - diff_output_loss: 0.2249 - error_output_accuracy: 0.7005 - diff_output_mae: 0.3624 - val_loss: 0.7301 - val_error_output_loss: 0.3350 - val_diff_output_loss: 0.2544 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.4147
# Epoch 25/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.7003 - error_output_loss: 0.3348 - diff_output_loss: 0.2248 - error_output_accuracy: 0.7170 - diff_output_mae: 0.3730 - val_loss: 0.8435 - val_error_output_loss: 0.3308 - val_diff_output_loss: 0.3806 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.5067
# Epoch 26/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.7158 - error_output_loss: 0.3326 - diff_output_loss: 0.2498 - error_output_accuracy: 0.6769 - diff_output_mae: 0.3789 - val_loss: 0.6583 - val_error_output_loss: 0.3309 - val_diff_output_loss: 0.1969 - val_error_output_accuracy: 0.6887 - val_diff_output_mae: 0.3618
# Epoch 27/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.6911 - error_output_loss: 0.3287 - diff_output_loss: 0.2331 - error_output_accuracy: 0.7028 - diff_output_mae: 0.3591 - val_loss: 0.6564 - val_error_output_loss: 0.3236 - val_diff_output_loss: 0.2069 - val_error_output_accuracy: 0.6887 - val_diff_output_mae: 0.3717
# Epoch 28/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.6824 - error_output_loss: 0.3283 - diff_output_loss: 0.2278 - error_output_accuracy: 0.7052 - diff_output_mae: 0.3754 - val_loss: 0.6345 - val_error_output_loss: 0.3185 - val_diff_output_loss: 0.1921 - val_error_output_accuracy: 0.7453 - val_diff_output_mae: 0.3518
# Epoch 29/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.6327 - error_output_loss: 0.3183 - diff_output_loss: 0.1908 - error_output_accuracy: 0.7052 - diff_output_mae: 0.3431 - val_loss: 0.6508 - val_error_output_loss: 0.3175 - val_diff_output_loss: 0.2114 - val_error_output_accuracy: 0.6698 - val_diff_output_mae: 0.3338
# Epoch 30/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.6262 - error_output_loss: 0.3155 - diff_output_loss: 0.1934 - error_output_accuracy: 0.7241 - diff_output_mae: 0.3333 - val_loss: 0.6533 - val_error_output_loss: 0.3163 - val_diff_output_loss: 0.2200 - val_error_output_accuracy: 0.6604 - val_diff_output_mae: 0.3336
# Epoch 31/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.6233 - error_output_loss: 0.3218 - diff_output_loss: 0.1880 - error_output_accuracy: 0.6981 - diff_output_mae: 0.3364 - val_loss: 0.6098 - val_error_output_loss: 0.3093 - val_diff_output_loss: 0.1892 - val_error_output_accuracy: 0.7453 - val_diff_output_mae: 0.3323
# Epoch 32/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.6297 - error_output_loss: 0.3131 - diff_output_loss: 0.2071 - error_output_accuracy: 0.6981 - diff_output_mae: 0.3435 - val_loss: 0.6205 - val_error_output_loss: 0.3059 - val_diff_output_loss: 0.2057 - val_error_output_accuracy: 0.7642 - val_diff_output_mae: 0.3270
# Epoch 33/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.6262 - error_output_loss: 0.3097 - diff_output_loss: 0.2114 - error_output_accuracy: 0.7335 - diff_output_mae: 0.3519 - val_loss: 0.6718 - val_error_output_loss: 0.3055 - val_diff_output_loss: 0.2604 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3556
# Epoch 34/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.6201 - error_output_loss: 0.3005 - diff_output_loss: 0.2177 - error_output_accuracy: 0.7170 - diff_output_mae: 0.3587 - val_loss: 0.5967 - val_error_output_loss: 0.2989 - val_diff_output_loss: 0.1963 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3304
# Epoch 35/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.5885 - error_output_loss: 0.3005 - diff_output_loss: 0.1887 - error_output_accuracy: 0.7217 - diff_output_mae: 0.3263 - val_loss: 0.5802 - val_error_output_loss: 0.2946 - val_diff_output_loss: 0.1872 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3378
# Epoch 36/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.6067 - error_output_loss: 0.2967 - diff_output_loss: 0.2130 - error_output_accuracy: 0.7311 - diff_output_mae: 0.3516 - val_loss: 0.5951 - val_error_output_loss: 0.2975 - val_diff_output_loss: 0.2008 - val_error_output_accuracy: 0.7453 - val_diff_output_mae: 0.3252
# Epoch 37/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.5855 - error_output_loss: 0.2934 - diff_output_loss: 0.1976 - error_output_accuracy: 0.7429 - diff_output_mae: 0.3467 - val_loss: 0.5675 - val_error_output_loss: 0.2900 - val_diff_output_loss: 0.1852 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3402
# Epoch 38/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.5958 - error_output_loss: 0.2942 - diff_output_loss: 0.2087 - error_output_accuracy: 0.7193 - diff_output_mae: 0.3532 - val_loss: 0.5708 - val_error_output_loss: 0.2890 - val_diff_output_loss: 0.1894 - val_error_output_accuracy: 0.7453 - val_diff_output_mae: 0.3314
# Epoch 39/100
# 14/14 [==============================] - 1s 58ms/step - loss: 0.5729 - error_output_loss: 0.2861 - diff_output_loss: 0.1959 - error_output_accuracy: 0.7406 - diff_output_mae: 0.3348 - val_loss: 0.5621 - val_error_output_loss: 0.2876 - val_diff_output_loss: 0.1849 - val_error_output_accuracy: 0.6792 - val_diff_output_mae: 0.3342
# Epoch 40/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.5836 - error_output_loss: 0.2867 - diff_output_loss: 0.2089 - error_output_accuracy: 0.7288 - diff_output_mae: 0.3591 - val_loss: 0.5561 - val_error_output_loss: 0.2827 - val_diff_output_loss: 0.1859 - val_error_output_accuracy: 0.7642 - val_diff_output_mae: 0.3264
# Epoch 41/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5747 - error_output_loss: 0.2874 - diff_output_loss: 0.2005 - error_output_accuracy: 0.7335 - diff_output_mae: 0.3360 - val_loss: 0.5673 - val_error_output_loss: 0.2783 - val_diff_output_loss: 0.2048 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3665
# Epoch 42/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.5795 - error_output_loss: 0.2821 - diff_output_loss: 0.2130 - error_output_accuracy: 0.7571 - diff_output_mae: 0.3483 - val_loss: 0.5455 - val_error_output_loss: 0.2773 - val_diff_output_loss: 0.1855 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3474
# Epoch 43/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.5444 - error_output_loss: 0.2781 - diff_output_loss: 0.1840 - error_output_accuracy: 0.7429 - diff_output_mae: 0.3322 - val_loss: 0.5462 - val_error_output_loss: 0.2778 - val_diff_output_loss: 0.1865 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3262
# Epoch 44/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5652 - error_output_loss: 0.2833 - diff_output_loss: 0.2003 - error_output_accuracy: 0.7500 - diff_output_mae: 0.3435 - val_loss: 0.5663 - val_error_output_loss: 0.2778 - val_diff_output_loss: 0.2067 - val_error_output_accuracy: 0.7547 - val_diff_output_mae: 0.3287
# Epoch 45/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.5724 - error_output_loss: 0.2776 - diff_output_loss: 0.2157 - error_output_accuracy: 0.7288 - diff_output_mae: 0.3693 - val_loss: 0.6103 - val_error_output_loss: 0.2796 - val_diff_output_loss: 0.2506 - val_error_output_accuracy: 0.7453 - val_diff_output_mae: 0.3483
# Epoch 46/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.5748 - error_output_loss: 0.2759 - diff_output_loss: 0.2224 - error_output_accuracy: 0.7665 - diff_output_mae: 0.3592 - val_loss: 0.6411 - val_error_output_loss: 0.2758 - val_diff_output_loss: 0.2859 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3767
# Epoch 47/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.5949 - error_output_loss: 0.2810 - diff_output_loss: 0.2372 - error_output_accuracy: 0.7406 - diff_output_mae: 0.3725 - val_loss: 0.5532 - val_error_output_loss: 0.2707 - val_diff_output_loss: 0.2037 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3255
# Epoch 48/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.5467 - error_output_loss: 0.2703 - diff_output_loss: 0.1994 - error_output_accuracy: 0.7476 - diff_output_mae: 0.3347 - val_loss: 0.5400 - val_error_output_loss: 0.2688 - val_diff_output_loss: 0.1940 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3246
# Epoch 49/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.5357 - error_output_loss: 0.2716 - diff_output_loss: 0.1889 - error_output_accuracy: 0.7476 - diff_output_mae: 0.3351 - val_loss: 0.5320 - val_error_output_loss: 0.2660 - val_diff_output_loss: 0.1926 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3473
# Epoch 50/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.5411 - error_output_loss: 0.2676 - diff_output_loss: 0.2005 - error_output_accuracy: 0.7571 - diff_output_mae: 0.3539 - val_loss: 0.5206 - val_error_output_loss: 0.2631 - val_diff_output_loss: 0.1854 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3324
# Epoch 51/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.5470 - error_output_loss: 0.2660 - diff_output_loss: 0.2091 - error_output_accuracy: 0.7571 - diff_output_mae: 0.3457 - val_loss: 0.5177 - val_error_output_loss: 0.2648 - val_diff_output_loss: 0.1817 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3351
# Epoch 52/100
# 14/14 [==============================] - 1s 48ms/step - loss: 0.5185 - error_output_loss: 0.2622 - diff_output_loss: 0.1847 - error_output_accuracy: 0.7476 - diff_output_mae: 0.3388 - val_loss: 0.5214 - val_error_output_loss: 0.2631 - val_diff_output_loss: 0.1878 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3359
# Epoch 53/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5311 - error_output_loss: 0.2640 - diff_output_loss: 0.1968 - error_output_accuracy: 0.7476 - diff_output_mae: 0.3402 - val_loss: 0.5225 - val_error_output_loss: 0.2600 - val_diff_output_loss: 0.1947 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3557
# Epoch 54/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5160 - error_output_loss: 0.2619 - diff_output_loss: 0.1865 - error_output_accuracy: 0.7807 - diff_output_mae: 0.3327 - val_loss: 0.5367 - val_error_output_loss: 0.2588 - val_diff_output_loss: 0.2119 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3748
# Epoch 55/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.5276 - error_output_loss: 0.2586 - diff_output_loss: 0.2017 - error_output_accuracy: 0.7689 - diff_output_mae: 0.3519 - val_loss: 0.5635 - val_error_output_loss: 0.2568 - val_diff_output_loss: 0.2395 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3927
# Epoch 56/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.5113 - error_output_loss: 0.2624 - diff_output_loss: 0.1803 - error_output_accuracy: 0.7689 - diff_output_mae: 0.3277 - val_loss: 0.5038 - val_error_output_loss: 0.2568 - val_diff_output_loss: 0.1801 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3305
# Epoch 57/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.5195 - error_output_loss: 0.2543 - diff_output_loss: 0.1997 - error_output_accuracy: 0.7877 - diff_output_mae: 0.3458 - val_loss: 0.5018 - val_error_output_loss: 0.2547 - val_diff_output_loss: 0.1821 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3321
# Epoch 58/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.4945 - error_output_loss: 0.2533 - diff_output_loss: 0.1766 - error_output_accuracy: 0.7712 - diff_output_mae: 0.3306 - val_loss: 0.5213 - val_error_output_loss: 0.2571 - val_diff_output_loss: 0.1984 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3253
# Epoch 59/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5009 - error_output_loss: 0.2561 - diff_output_loss: 0.1804 - error_output_accuracy: 0.7594 - diff_output_mae: 0.3311 - val_loss: 0.5126 - val_error_output_loss: 0.2518 - val_diff_output_loss: 0.1975 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3493
# Epoch 60/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.4959 - error_output_loss: 0.2536 - diff_output_loss: 0.1791 - error_output_accuracy: 0.7736 - diff_output_mae: 0.3227 - val_loss: 0.5058 - val_error_output_loss: 0.2504 - val_diff_output_loss: 0.1920 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3359
# Epoch 61/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.5183 - error_output_loss: 0.2545 - diff_output_loss: 0.2002 - error_output_accuracy: 0.7689 - diff_output_mae: 0.3439 - val_loss: 0.4943 - val_error_output_loss: 0.2500 - val_diff_output_loss: 0.1811 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3334
# Epoch 62/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.4789 - error_output_loss: 0.2530 - diff_output_loss: 0.1627 - error_output_accuracy: 0.7524 - diff_output_mae: 0.2993 - val_loss: 0.5279 - val_error_output_loss: 0.2470 - val_diff_output_loss: 0.2199 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3775
# Epoch 63/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.5030 - error_output_loss: 0.2536 - diff_output_loss: 0.1879 - error_output_accuracy: 0.7665 - diff_output_mae: 0.3392 - val_loss: 0.5002 - val_error_output_loss: 0.2505 - val_diff_output_loss: 0.1887 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3415
# Epoch 64/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4749 - error_output_loss: 0.2514 - diff_output_loss: 0.1619 - error_output_accuracy: 0.7759 - diff_output_mae: 0.3075 - val_loss: 0.5021 - val_error_output_loss: 0.2491 - val_diff_output_loss: 0.1916 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3290
# Epoch 65/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4875 - error_output_loss: 0.2511 - diff_output_loss: 0.1760 - error_output_accuracy: 0.7759 - diff_output_mae: 0.3197 - val_loss: 0.4988 - val_error_output_loss: 0.2444 - val_diff_output_loss: 0.1954 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3432
# Epoch 66/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4869 - error_output_loss: 0.2468 - diff_output_loss: 0.1819 - error_output_accuracy: 0.7830 - diff_output_mae: 0.3313 - val_loss: 0.4945 - val_error_output_loss: 0.2459 - val_diff_output_loss: 0.1903 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3340
# Epoch 67/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.5000 - error_output_loss: 0.2485 - diff_output_loss: 0.1931 - error_output_accuracy: 0.7948 - diff_output_mae: 0.3380 - val_loss: 0.4950 - val_error_output_loss: 0.2474 - val_diff_output_loss: 0.1886 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3244
# Epoch 68/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4922 - error_output_loss: 0.2470 - diff_output_loss: 0.1863 - error_output_accuracy: 0.7830 - diff_output_mae: 0.3330 - val_loss: 0.5010 - val_error_output_loss: 0.2435 - val_diff_output_loss: 0.1970 - val_error_output_accuracy: 0.7925 - val_diff_output_mae: 0.3274
# Epoch 69/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.4952 - error_output_loss: 0.2468 - diff_output_loss: 0.1877 - error_output_accuracy: 0.7689 - diff_output_mae: 0.3397 - val_loss: 0.4799 - val_error_output_loss: 0.2403 - val_diff_output_loss: 0.1813 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3330
# Epoch 70/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.5045 - error_output_loss: 0.2451 - diff_output_loss: 0.2020 - error_output_accuracy: 0.7830 - diff_output_mae: 0.3426 - val_loss: 0.4957 - val_error_output_loss: 0.2421 - val_diff_output_loss: 0.1954 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3264
# Epoch 71/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.4932 - error_output_loss: 0.2451 - diff_output_loss: 0.1898 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3267 - val_loss: 0.4854 - val_error_output_loss: 0.2386 - val_diff_output_loss: 0.1899 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3413
# Epoch 72/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4902 - error_output_loss: 0.2416 - diff_output_loss: 0.1916 - error_output_accuracy: 0.7783 - diff_output_mae: 0.3345 - val_loss: 0.5238 - val_error_output_loss: 0.2424 - val_diff_output_loss: 0.2235 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3347
# Epoch 73/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4841 - error_output_loss: 0.2427 - diff_output_loss: 0.1838 - error_output_accuracy: 0.7901 - diff_output_mae: 0.3335 - val_loss: 0.5313 - val_error_output_loss: 0.2441 - val_diff_output_loss: 0.2286 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3417
# Epoch 74/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4819 - error_output_loss: 0.2378 - diff_output_loss: 0.1862 - error_output_accuracy: 0.7948 - diff_output_mae: 0.3269 - val_loss: 0.4866 - val_error_output_loss: 0.2448 - val_diff_output_loss: 0.1851 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3273
# Epoch 75/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.4782 - error_output_loss: 0.2422 - diff_output_loss: 0.1802 - error_output_accuracy: 0.7736 - diff_output_mae: 0.3214 - val_loss: 0.4781 - val_error_output_loss: 0.2382 - val_diff_output_loss: 0.1848 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3349
# Epoch 76/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4712 - error_output_loss: 0.2409 - diff_output_loss: 0.1749 - error_output_accuracy: 0.7689 - diff_output_mae: 0.3191 - val_loss: 0.5229 - val_error_output_loss: 0.2340 - val_diff_output_loss: 0.2351 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3897
# Epoch 77/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.5113 - error_output_loss: 0.2455 - diff_output_loss: 0.2114 - error_output_accuracy: 0.7901 - diff_output_mae: 0.3524 - val_loss: 0.4836 - val_error_output_loss: 0.2356 - val_diff_output_loss: 0.1946 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3560
# Epoch 78/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4926 - error_output_loss: 0.2455 - diff_output_loss: 0.1915 - error_output_accuracy: 0.7830 - diff_output_mae: 0.3370 - val_loss: 0.5042 - val_error_output_loss: 0.2385 - val_diff_output_loss: 0.2096 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3508
# Epoch 79/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4633 - error_output_loss: 0.2399 - diff_output_loss: 0.1679 - error_output_accuracy: 0.7877 - diff_output_mae: 0.3095 - val_loss: 0.4965 - val_error_output_loss: 0.2351 - val_diff_output_loss: 0.2072 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3338
# Epoch 80/100
# 14/14 [==============================] - 1s 46ms/step - loss: 0.4900 - error_output_loss: 0.2388 - diff_output_loss: 0.1980 - error_output_accuracy: 0.7925 - diff_output_mae: 0.3426 - val_loss: 0.4942 - val_error_output_loss: 0.2368 - val_diff_output_loss: 0.2034 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3318
# Epoch 81/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4744 - error_output_loss: 0.2351 - diff_output_loss: 0.1844 - error_output_accuracy: 0.7901 - diff_output_mae: 0.3239 - val_loss: 0.5052 - val_error_output_loss: 0.2372 - val_diff_output_loss: 0.2123 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3368
# Epoch 82/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.4837 - error_output_loss: 0.2354 - diff_output_loss: 0.1946 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3308 - val_loss: 0.4644 - val_error_output_loss: 0.2328 - val_diff_output_loss: 0.1788 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3397
# Epoch 83/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4734 - error_output_loss: 0.2329 - diff_output_loss: 0.1877 - error_output_accuracy: 0.7759 - diff_output_mae: 0.3407 - val_loss: 0.4792 - val_error_output_loss: 0.2337 - val_diff_output_loss: 0.1921 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3319
# Epoch 84/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.4781 - error_output_loss: 0.2358 - diff_output_loss: 0.1887 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3390 - val_loss: 0.4705 - val_error_output_loss: 0.2308 - val_diff_output_loss: 0.1874 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3389
# Epoch 85/100
# 14/14 [==============================] - 1s 45ms/step - loss: 0.4409 - error_output_loss: 0.2323 - diff_output_loss: 0.1565 - error_output_accuracy: 0.7901 - diff_output_mae: 0.3067 - val_loss: 0.4915 - val_error_output_loss: 0.2277 - val_diff_output_loss: 0.2130 - val_error_output_accuracy: 0.7642 - val_diff_output_mae: 0.3711
# Epoch 86/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.4810 - error_output_loss: 0.2333 - diff_output_loss: 0.1960 - error_output_accuracy: 0.7807 - diff_output_mae: 0.3367 - val_loss: 0.4857 - val_error_output_loss: 0.2285 - val_diff_output_loss: 0.2059 - val_error_output_accuracy: 0.7642 - val_diff_output_mae: 0.3635
# Epoch 87/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4707 - error_output_loss: 0.2306 - diff_output_loss: 0.1877 - error_output_accuracy: 0.7783 - diff_output_mae: 0.3253 - val_loss: 0.4661 - val_error_output_loss: 0.2288 - val_diff_output_loss: 0.1851 - val_error_output_accuracy: 0.7642 - val_diff_output_mae: 0.3376
# Epoch 88/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4936 - error_output_loss: 0.2311 - diff_output_loss: 0.2110 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3421 - val_loss: 0.4794 - val_error_output_loss: 0.2310 - val_diff_output_loss: 0.1983 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3629
# Epoch 89/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.4560 - error_output_loss: 0.2330 - diff_output_loss: 0.1718 - error_output_accuracy: 0.7830 - diff_output_mae: 0.3233 - val_loss: 0.4738 - val_error_output_loss: 0.2313 - val_diff_output_loss: 0.1909 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3295
# Epoch 90/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.4517 - error_output_loss: 0.2331 - diff_output_loss: 0.1673 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3148 - val_loss: 0.4724 - val_error_output_loss: 0.2279 - val_diff_output_loss: 0.1936 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3432
# Epoch 91/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.4480 - error_output_loss: 0.2311 - diff_output_loss: 0.1631 - error_output_accuracy: 0.7854 - diff_output_mae: 0.3233 - val_loss: 0.4867 - val_error_output_loss: 0.2281 - val_diff_output_loss: 0.2055 - val_error_output_accuracy: 0.7830 - val_diff_output_mae: 0.3366
# Epoch 92/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.4658 - error_output_loss: 0.2333 - diff_output_loss: 0.1807 - error_output_accuracy: 0.7901 - diff_output_mae: 0.3208 - val_loss: 0.4647 - val_error_output_loss: 0.2253 - val_diff_output_loss: 0.1883 - val_error_output_accuracy: 0.7736 - val_diff_output_mae: 0.3348
# 4/4 [==============================] - 4s 12ms/step
# Validation Difficulty MAE: 0.34
# Model trained and saved!

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)
tutor_loaded.model.summary()
# Out:
# Dataset rows without duplicate: 530
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 103
#   Omission of Letters: 108
#   Silent Letters: 106
#   Transpositions: 106
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  embedding (Embedding)       (None, 8, 128)               3712      ['input_1[0][0]']
#
#  bidirectional (Bidirection  (None, 8, 512)               788480    ['embedding[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 8, 256)               656384    ['bidirectional[0][0]']
#  onal)
#
#  global_max_pooling1d (Glob  (None, 256)                  0         ['bidirectional_1[0][0]']
#  alMaxPooling1D)
#
#  input_2 (InputLayer)        [(None, 6)]                  0         []
#
#  concatenate (Concatenate)   (None, 262)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense (Dense)               (None, 128)                  33664     ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  error_output (Dense)        (None, 5)                    645       ['dropout[0][0]']
#
#  diff_output (Dense)         (None, 1)                    129       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1483014 (5.66 MB)
# Trainable params: 1483014 (5.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tutor_loaded = SpellingTutor(
    dataset_path="final.csv",
    filepath="spelling_tutor_model.keras",
    metadata_path="spelling_tutor_metadata.json"
)

test_words = ['nknowlege', 'garbege', 'jujeee', 'choklat', 'glisen','chicken']
results = []
previous_score = 0

for word in test_words:
    result = tutor_loaded.process_word(word)
    score_change = result['score'] - previous_score
    results.append({
        'word': result['word'],
        'correct': result['correct'],
        'error_types': result['error_types'],
        'confidences': result['confidences'],
        'max_confidence_type': result['max_confidence_type'],
        'confidence': result['confidence'],
        'predicted_difficulty': result['predicted_difficulty'],
        'actual_difficulty': result['actual_difficulty'],
        'score_change': score_change,
        'total_score': result['score'],
        'streak': result['streak'],
        'difficulty': result['game_difficulty']
    })
    previous_score = result['score']
    print(f"\nWord: {result['word']}")
    print(f"Status: {'✓ Correct' if result['correct'] else '✗ Incorrect'}")
    if not result['correct']:
        error_types_str = ', '.join([f"{et} ({result['confidences'][et]:.2%})" for et in result['error_types']])
        print(f"Error Types: {error_types_str}")
        print(f"Max Confidence Error Type: {result['max_confidence_type']} ({result['confidence']:.2%})")
    print(f"Predicted Difficulty: {result['predicted_difficulty']} | Actual Difficulty: {result['actual_difficulty']}")
    print(f"Score: {result['score']} | Streak: {result['streak']} | Game Difficulty: {result['game_difficulty']}")

grouped_results = defaultdict(lambda: {'count': 0, 'total_score_change': 0, 'words': [], 'avg_difficulty': 0})

for result in results:
    error_type = result['max_confidence_type']
    grouped_results[error_type]['count'] += 1
    grouped_results[error_type]['total_score_change'] += result['score_change']
    grouped_results[error_type]['words'].append(result['word'])
    grouped_results[error_type]['avg_difficulty'] += result['actual_difficulty']

print("\n=== Grouped Results ===")
for error_type, data in grouped_results.items():
    avg_diff = data['avg_difficulty'] / data['count'] if data['count'] > 0 else 0
    rounded_difficulty_level = round(avg_diff)
    print(f"Error Type: {error_type}")
    print(f"  Count: {data['count']}")
    print(f"  Total Score Change: {data['total_score_change']}")
    print(f"  Average Difficulty: {avg_diff:.2f}")
    print(f"  Words: {', '.join(data['words'])}")

    if hasattr(tutor_loaded, "processor") and hasattr(tutor_loaded.processor, "df"):
        error_type_words = tutor_loaded.processor.df[
            (tutor_loaded.processor.df['Error_Type'].apply(lambda x: error_type in x)) &
            (tutor_loaded.processor.df['Difficulty_Level'] == rounded_difficulty_level)
        ]

        if not error_type_words.empty:
            suggested_words = error_type_words['Incorrect_Word'].sample(min(5, len(error_type_words))).tolist()
            print(f"  Suggested Words:")
            for i, word in enumerate(suggested_words, 1):
                difficulty = tutor_loaded.processor.get_difficulty(word)
                print(f"    {i}. {word}")
        else:
            print("No suggested words available.")
    else:
        print("dataset not loaded correctly.")
# Out:
# Dataset rows without duplicate: 530
# Error types: ['Addition of Letters', 'Letter-Phoneme Correspondence', 'Omission of Letters', 'Silent Letters', 'Transpositions']
# max difficulty: 4
# Error type counts:
#   Addition of Letters: 108
#   Letter-Phoneme Correspondence: 103
#   Omission of Letters: 108
#   Silent Letters: 106
#   Transpositions: 106
# 1/1 [==============================] - 4s 4s/step
#
# Word: nknowlege
# Status: ✗ Incorrect
# Error Types: Unknown (23.93%)
# Max Confidence Error Type: Omission of Letters (23.93%)
# Predicted Difficulty: 3.45 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: garbege
# Status: ✗ Incorrect
# Error Types: Unknown (27.47%)
# Max Confidence Error Type: Omission of Letters (27.47%)
# Predicted Difficulty: 3.08 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 30ms/step
#
# Word: jujeee
# Status: ✗ Incorrect
# Error Types: Transpositions (47.85%)
# Max Confidence Error Type: Transpositions (47.85%)
# Predicted Difficulty: 2.51 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 27ms/step
#
# Word: choklat
# Status: ✗ Incorrect
# Error Types: Unknown (26.64%)
# Max Confidence Error Type: Omission of Letters (26.64%)
# Predicted Difficulty: 3.17 | Actual Difficulty: 0
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: glisen
# Status: ✗ Incorrect
# Error Types: Silent Letters (44.73%)
# Max Confidence Error Type: Silent Letters (44.73%)
# Predicted Difficulty: 3.05 | Actual Difficulty: 3
# Score: 0 | Streak: 0 | Game Difficulty: 1
# 1/1 [==============================] - 0s 29ms/step
#
# Word: chicken
# Status: ✓ Correct
# Predicted Difficulty: 3.0 | Actual Difficulty: 0
# Score: 15 | Streak: 1 | Game Difficulty: 1
#
# === Grouped Results ===
# Error Type: Omission of Letters
#   Count: 3
#   Total Score Change: 0
#   Average Difficulty: 0.00
#   Words: nknowlege, garbege, choklat
# No suggested words available.
# Error Type: Transpositions
#   Count: 1
#   Total Score Change: 0
#   Average Difficulty: 0.00
#   Words: jujeee
# No suggested words available.
# Error Type: Silent Letters
#   Count: 1
#   Total Score Change: 0
#   Average Difficulty: 3.00
#   Words: glisen
#   Suggested Words:
#     1. debri
#     2. sofen
#     3. rench
#     4. iland
#     5. reath
# Error Type: Correct
#   Count: 1
#   Total Score Change: 15
#   Average Difficulty: 0.00
#   Words: chicken
# No suggested words available.

# %%
error_types = list(grouped_results.keys())
error_counts = [grouped_results[et]['count'] for et in error_types]

plt.figure(figsize=(10, 6))
plt.bar(error_types, error_counts, color='skyblue')

plt.xlabel('Error Types')
plt.ylabel('Count')
plt.title('Error Type Distribution')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
